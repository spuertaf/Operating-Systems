# %%
from image import ImageOperations, Image
from tests import plot_benchmarking

import cv2
from PIL import Image as Img

# %%
img = cv2.imread("C:\\Users\\puert\\Downloads\\RotacionTraslacion\\RotacionTraslacion\\img\\dog.jpg")

# %%
Img.fromarray(Image(img).rotate(15))
# Out:
# <PIL.Image.Image image mode=RGB size=1471x1471>

# %%
plot_benchmarking(["C:\\Users\\puert\\Downloads\\RotacionTraslacion\\RotacionTraslacion\\img\\dog.jpg"])
# Out:
# [   Non parallel img rotation        size file_name
# 0                     0.0006  (100, 100)   dog.jpg
# 1                     0.0012  (200, 200)   dog.jpg
# 2                     0.0007  (300, 300)   dog.jpg]
